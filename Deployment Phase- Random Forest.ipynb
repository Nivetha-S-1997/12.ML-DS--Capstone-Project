# %%
import pandas as pd
import pickle
import numpy as np

# %%
dataset=pd.read_csv('Preprocessed CO2 Emission.csv')
dataset
# Out:
#      Model_Year  Make  Model  Vehicle_Class  Engine_Size  Cylinders  \
# 0          2021     0    355              0          2.4          4
# 1          2021     0    438             13          3.5          6
# 2          2021     0    506              7          2.0          4
# 3          2021     0    507              7          2.0          4
# 4          2021     0    604              0          2.0          4
# ..          ...   ...    ...            ...          ...        ...
# 930        2021    37    683              7          2.0          4
# 931        2021    37    684              7          2.0          4
# 932        2021    37    685              7          2.0          4
# 933        2021    37    686              8          2.0          4
# 934        2021    37    687              8          2.0          4
#
#      Transmission  Fuel_Consumption_in_City(L/100 km)  \
# 0               6                                 9.9
# ...

# %%
loaded_model=pickle.load(open('Final_model_randomforest.sav','rb'))

# %%
Engine_Size=input('Enter Engine_Size: ')
Fuel_Consumption_comb=input('Fuel_Consumption_comb(L/100km): ')
# Out:
# Enter Engine_Size:  3.5
# Fuel_Consumption_comb(L/100km):  12

# %%
result=loaded_model.predict([[Engine_Size,Fuel_Consumption_comb]])

# %%
result
# Out:
# array([281.20533333])
